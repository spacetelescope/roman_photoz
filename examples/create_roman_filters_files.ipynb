# %% [markdown]
# From https://github.com/LSSTDESC/rail_lephare/blob/main/examples/cosmos_demo.ipynb

# %%
from matplotlib import pyplot as plt
from roman_photoz import RomanCatalogProcess
from roman_photoz.default_config_file import default_roman_config
import os
# Out:
# LEPHAREDIR is being set to the default cache directory:
# /Users/mteodoro/Library/Caches/lephare/data
# More than 1Gb may be written there.
# LEPHAREWORK is being set to the default cache directory:
# /Users/mteodoro/Library/Caches/lephare/work
# Default work cache is already linked.
# This is linked to the run directory:
# /Users/mteodoro/Library/Caches/lephare/runs/20250204T152746

# %%
config_file = default_roman_config
config_file
# Out:
# {'ADAPT_BAND': '5',
#  'ADAPT_CONTEXT': '-1',
#  'ADAPT_LIM': '1.5,23.0',
#  'ADAPT_MODBIN': '1,1000',
#  'ADAPT_ZBIN': '0.01,6',
#  'ADDITIONAL_MAG': 'none',
#  'ADD_DUSTEM': 'NO',
#  'ADD_EMLINES': '0,10000',
#  'AGE_RANGE': '0.,15.e9',
#  'AUTO_ADAPT': 'NO',
#  'CAT_FMT': 'MEME',
#  'CAT_IN': 'roman_simulated_catalog.in',
#  'CAT_LINES': '0,1000000000',
#  'CAT_MAG': 'AB',
#  'CAT_OUT': 'roman_simulated_catalog.out',
#  'CAT_TYPE': 'LONG',
#  'CHI2_OUT': 'NO',
#  'COSMOLOGY': '70,0.3,0.7',
#  'DZ_WIN': '1.0',
#  'EBV_RANGE': '0,9',
#  'EB_V': '0.,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.5',
#  'EM_DISPERSION': '0.5,0.75,1.,1.5,2.',
#  'EM_LINES': 'EMP_UV',
#  'ERR_FACTOR': '1.5',
#  'ERR_SCALE': '0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.05,0.05,0.05,0.05,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.05,0.05,0.05,0.05,0.1,0.2,0.3',
#  'EXTERNALZ_FILE': 'NONE',
#  'EXTINC_LAW': 'SMC_prevot.dat,SB_calzetti.dat,SB_calzetti_bump1.dat,SB_calzetti_bump2.dat',
#  'FILTER_CALIB': '0,0,0,0,0,0,0,0',
#  'FILTER_FILE': 'filter_roman',
#  'FILTER_LIST': 'roman/roman_F062.pb,roman/roman_F087.pb,roman/roman_F106.pb,roman/roman_F129.pb,roman/roman_F146.pb,roman/roman_F158.pb,roman/roman_F184.pb,roman/roman_F213.pb',
#  'FILTER_REP': '/Users/mteodoro/Library/Caches/lephare/data/filt',
#  'FIR_CONT': '-1',
#  'FIR_FREESCALE': 'YES',
#  'FIR_LIB': 'NONE',
#  'FIR_LMIN': '7.0',
#  'FIR_SCALE': '-1',
#  'FIR_SUBSTELLAR': 'NO',
#  'FORB_CONTEXT': '-1',
#  'GAL_FSCALE': '1.',
#  'GAL_LIB': 'LIB_CE',
#  'GAL_LIB_IN': 'LIB_CE',
#  'GAL_LIB_OUT': 'ROMAN_SIMULATED_MAGS',
#  'GAL_SED': 'examples/COSMOS_MOD.list',
#  'GLB_CONTEXT': '0',
#  'INP_TYPE': 'F',
#  'LIB_ASCII': 'YES',
#  'LIMITS_MAPP_CUT': '90',
#  'LIMITS_MAPP_REF': '1',
#  'LIMITS_MAPP_SEL': '1',
#  'LIMITS_ZBIN': '0,99',
#  'MABS_CONTEXT': '33556478',
#  'MABS_FILT': '1,2,3,4',
#  'MABS_METHOD': '1',
#  'MABS_REF': '11',
#  'MABS_ZBIN': '0,0.5,2,4,6',
#  'MAGTYPE': 'AB',
#  'MAG_ABS': '-24,-5',
#  'MAG_ABS_QSO': '-30,-10',
#  'MAG_REF': '3',
#  'MIN_THRES': '0.02',
#  'MOD_EXTINC': '0,0',
#  'PARA_OUT': '/Users/mteodoro/Library/Caches/lephare/data/examples/output.para',
#  'PDZ_OUT': 'test',
#  'PDZ_TYPE': 'BAY_ZG',
#  'QSO_FSCALE': '1.',
#  'QSO_LIB': 'LIB_QSO',
#  'QSO_LIB_IN': 'LIB_QSO',
#  'QSO_LIB_OUT': 'QSO_COSMOS',
#  'QSO_SED': 'sed/QSO/SALVATO09/AGN_MOD.list',
#  'RF_COLORS': '32,4,4,13',
#  'RM_DISCREPANT_BD': '500',
#  'SPEC_OUT': 'NO',
#  'STAR_FSCALE': '3.432E-09',
#  'STAR_LIB': 'LIB_STAR',
#  'STAR_LIB_IN': 'LIB_STAR',
#  'STAR_LIB_OUT': 'STAR_COSMOS',
#  'STAR_SED': 'sed/STAR/STAR_MOD_ALL.list',
#  'TRANS_TYPE': '1',
#  'VERBOSE': 'NO',
#  'ZFIX': 'NO',
#  'ZGRID_TYPE': '0',
#  'ZPHOTLIB': 'ROMAN_SIMULATED_MAGS',
#  'Z_INTERP': 'YES',
#  'Z_METHOD': 'BEST',
#  'Z_RANGE': '0.,99.99',
#  'Z_STEP': '0.01,0.,7.'}

# %%
config_file["Z_STEP"] = ".1,0.,7."
config_file["MOD_EXTINC"] = "18,26,26,33,26,33,26,33"
config_file["EXTINC_LAW"] = ("SMC_prevot.dat,SB_calzetti.dat,SB_calzetti_bump1.dat,SB_calzetti_bump2.dat")
config_file["EM_LINES"] = "EMP_UV"
config_file["EM_DISPERSION"] = "0.5,1.,1.5"

config_file
# Out:
# {'ADAPT_BAND': '5',
#  'ADAPT_CONTEXT': '-1',
#  'ADAPT_LIM': '1.5,23.0',
#  'ADAPT_MODBIN': '1,1000',
#  'ADAPT_ZBIN': '0.01,6',
#  'ADDITIONAL_MAG': 'none',
#  'ADD_DUSTEM': 'NO',
#  'ADD_EMLINES': '0,10000',
#  'AGE_RANGE': '0.,15.e9',
#  'AUTO_ADAPT': 'NO',
#  'CAT_FMT': 'MEME',
#  'CAT_IN': 'roman_simulated_catalog.in',
#  'CAT_LINES': '0,1000000000',
#  'CAT_MAG': 'AB',
#  'CAT_OUT': 'roman_simulated_catalog.out',
#  'CAT_TYPE': 'LONG',
#  'CHI2_OUT': 'NO',
#  'COSMOLOGY': '70,0.3,0.7',
#  'DZ_WIN': '1.0',
#  'EBV_RANGE': '0,9',
#  'EB_V': '0.,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.5',
#  'EM_DISPERSION': '0.5,1.,1.5',
#  'EM_LINES': 'EMP_UV',
#  'ERR_FACTOR': '1.5',
#  'ERR_SCALE': '0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.05,0.05,0.05,0.05,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.02,0.05,0.05,0.05,0.05,0.1,0.2,0.3',
#  'EXTERNALZ_FILE': 'NONE',
#  'EXTINC_LAW': 'SMC_prevot.dat,SB_calzetti.dat,SB_calzetti_bump1.dat,SB_calzetti_bump2.dat',
#  'FILTER_CALIB': '0,0,0,0,0,0,0,0',
#  'FILTER_FILE': 'filter_roman',
#  'FILTER_LIST': 'roman/roman_F062.pb,roman/roman_F087.pb,roman/roman_F106.pb,roman/roman_F129.pb,roman/roman_F146.pb,roman/roman_F158.pb,roman/roman_F184.pb,roman/roman_F213.pb',
#  'FILTER_REP': '/Users/mteodoro/Library/Caches/lephare/data/filt',
#  'FIR_CONT': '-1',
#  'FIR_FREESCALE': 'YES',
#  'FIR_LIB': 'NONE',
#  'FIR_LMIN': '7.0',
#  'FIR_SCALE': '-1',
#  'FIR_SUBSTELLAR': 'NO',
#  'FORB_CONTEXT': '-1',
#  'GAL_FSCALE': '1.',
#  'GAL_LIB': 'LIB_CE',
#  'GAL_LIB_IN': 'LIB_CE',
#  'GAL_LIB_OUT': 'ROMAN_SIMULATED_MAGS',
#  'GAL_SED': 'examples/COSMOS_MOD.list',
#  'GLB_CONTEXT': '0',
#  'INP_TYPE': 'F',
#  'LIB_ASCII': 'YES',
#  'LIMITS_MAPP_CUT': '90',
#  'LIMITS_MAPP_REF': '1',
#  'LIMITS_MAPP_SEL': '1',
#  'LIMITS_ZBIN': '0,99',
#  'MABS_CONTEXT': '33556478',
#  'MABS_FILT': '1,2,3,4',
#  'MABS_METHOD': '1',
#  'MABS_REF': '11',
#  'MABS_ZBIN': '0,0.5,2,4,6',
#  'MAGTYPE': 'AB',
#  'MAG_ABS': '-24,-5',
#  'MAG_ABS_QSO': '-30,-10',
#  'MAG_REF': '3',
#  'MIN_THRES': '0.02',
#  'MOD_EXTINC': '18,26,26,33,26,33,26,33',
#  'PARA_OUT': '/Users/mteodoro/Library/Caches/lephare/data/examples/output.para',
#  'PDZ_OUT': 'test',
#  'PDZ_TYPE': 'BAY_ZG',
#  'QSO_FSCALE': '1.',
#  'QSO_LIB': 'LIB_QSO',
#  'QSO_LIB_IN': 'LIB_QSO',
#  'QSO_LIB_OUT': 'QSO_COSMOS',
#  'QSO_SED': 'sed/QSO/SALVATO09/AGN_MOD.list',
#  'RF_COLORS': '32,4,4,13',
#  'RM_DISCREPANT_BD': '500',
#  'SPEC_OUT': 'NO',
#  'STAR_FSCALE': '3.432E-09',
#  'STAR_LIB': 'LIB_STAR',
#  'STAR_LIB_IN': 'LIB_STAR',
#  'STAR_LIB_OUT': 'STAR_COSMOS',
#  'STAR_SED': 'sed/STAR/STAR_MOD_ALL.list',
#  'TRANS_TYPE': '1',
#  'VERBOSE': 'NO',
#  'ZFIX': 'NO',
#  'ZGRID_TYPE': '0',
#  'ZPHOTLIB': 'ROMAN_SIMULATED_MAGS',
#  'Z_INTERP': 'YES',
#  'Z_METHOD': 'BEST',
#  'Z_RANGE': '0.,99.99',
#  'Z_STEP': '.1,0.,7.'}

# %%
rcp = RomanCatalogProcess(config_filename=config_file)

# %%
rcp.process()
# Out:
# Registry file downloaded and saved as data_registry.txt.
# Checking/downloading 423 files...
# Future completed with an exception: File 'filt/roman/roman_F062.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F087.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F106.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F129.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F146.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F158.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F184.pb' is not in the registry.
# Future completed with an exception: File 'filt/roman/roman_F213.pb' is not in the registry.
# 415 completed.
# All files downloaded successfully and are non-empty.
# Checking/downloading 2 files...
# 2 completed.
# All files downloaded successfully and are non-empty.
# 8
# rail_lephare is setting the Z_STEP config to 0.01,0.0,3.0 based on the informer params.
# User defined LEPHAREDIR is set. Code runs depend on all required
# auxiliary data being present at /Users/mteodoro/Library/Caches/lephare/data.
# User defined LEPHAREWORK is set. All intermediate files will be written to:
#  /Users/mteodoro/Library/Caches/lephare/runs/inform_roman
# Inserting handle into data store.  input: None, inform_roman
# # NAME                        IDENT      Lbda_mean Lbeff(Vega)       FWHM     AB-cor    TG-cor      VEGA M_sun(AB)   CALIB      Lb_eff    Fac_corr
# roman_F062.pb                 1             0.6434      0.6146      0.2191    0.1529    0.2578  -21.5544    4.6702       0      0.6242      1.0000
# roman_F087.pb                 2             0.8765      0.8653      0.2122    0.4940    0.7327  -22.5985    4.5149       0      0.8673      1.0000
# roman_F106.pb                 3             1.0652      1.0465      0.2627    0.6531  -99.0000  -23.1806    4.5240       0      1.0538      1.0000
# roman_F129.pb                 4             1.3005      1.2761      0.3191    0.9589  -99.0000  -23.9200    4.5715       0      1.2867      1.0000
# roman_F146.pb                 5             1.5378      1.3054      0.9562    1.0239  -99.0000  -24.2202    4.6364       0      1.4039      1.0000
# roman_F158.pb                 6             1.5875      1.5580      0.3889    1.2910  -99.0000  -24.6852    4.6689       0      1.5706      1.0000
# roman_F184.pb                 7             1.8466      1.8292      0.3142    1.5525  -99.0000  -25.2839    4.8671       0      1.8370      1.0000
# roman_F213.pb                 8             2.1306      2.1117      0.3467    1.8066  -99.0000  -25.8493    5.1067       0      2.1205      1.0000
# {'star_sed': '/Users/mteodoro/Library/Caches/lephare/data/sed/STAR/STAR_MOD_ALL.list'}
# #######################################
# # It s translating SEDs to binary library #
# # with the following options :
# # Config file     :
# # Library type     : STAR
# # STAR_SED    :/Users/mteodoro/Library/Caches/lephare/data/sed/STAR/STAR_MOD_ALL.list
# # STAR_LIB    :LIB_STAR
# # STAR_LIB doc:/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_STAR.doc
# # STAR_FSCALE :0.0000
# #######################################
# Number of SED in the list 254
#  All files opened
# #######################################
# # It s computing the SYNTHETIC MAGNITUDES #
# # For Gal/QSO libraries with these OPTIONS #
# # with the following options :
# # Config file     :
# # Filter file     : filter_roman
# # Magnitude type     : AB
# # COSMOLOGY   :70.0000,0.3000,0.7000
# # STAR_LIB_IN    :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_STAR(.doc & .bin)
# # STAR_LIB_OUT   :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_mag/STAR_COSMOS(.doc & .bin)
# # LIB_ASCII   YES
# # CREATION_DATE Tue Feb 18 08:24:56 2025
# #############################################
# {'gal_sed': '/Users/mteodoro/Library/Caches/lephare/data/examples/COSMOS_MOD.list'}
# #######################################
# # It s translating SEDs to binary library #
# # with the following options :
# # Config file     :
# # Library type     : GAL
# # GAL_SED    :/Users/mteodoro/Library/Caches/lephare/data/examples/COSMOS_MOD.list
# # GAL_LIB    :LIB_CE
# # GAL_LIB doc:/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_CE.doc
# # GAL_LIB phys:/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_CE.phys
# # SEL_AGE    :none
# # GAL_FSCALE :1.0000
# # AGE_RANGE   0.0000 15000000000.0000
# #######################################
# Number of SED in the list 31
#  All files opened
# #######################################
# # It s computing the SYNTHETIC MAGNITUDES #
# # For Gal/QSO libraries with these OPTIONS #
# # with the following options :
# # Config file     :
# # Filter file     : filter_roman
# # Magnitude type     : AB
# # GAL_LIB_IN    :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_CE(.doc & .bin)
# # GAL_LIB_OUT   :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_mag/ROMAN_SIMULATED_MAGS(.doc & .bin)
# # ZGRID_TYPE   :0
# # Z_STEP   :0.0100 0.0000 3.0000
# # COSMOLOGY   :70.0000,0.3000,0.7000
# # EXTINC_LAW   :SMC_prevot.dat SB_calzetti.dat SB_calzetti_bump1.dat SB_calzetti_bump2.dat
# # MOD_EXTINC   :18 26 26 33 26 33 26 33
# # EB_V   :0.0000 0.0500 0.1000 0.1500 0.2000 0.2500 0.3000 0.3500 0.4000 0.5000
# # EM_LINES   EMP_UV
# # EM_DISPERSION   0.5000,0.7500,1.0000,1.5000,2.0000,
# # LIB_ASCII   YES
# # CREATION_DATE Tue Feb 18 08:24:56 2025
# #############################################
# {'qso_sed': '/Users/mteodoro/Library/Caches/lephare/data/sed/QSO/SALVATO09/AGN_MOD.list'}
# #######################################
# # It s translating SEDs to binary library #
# # with the following options :
# # Config file     :
# # Library type     : QSO
# # QSO_SED    :/Users/mteodoro/Library/Caches/lephare/data/sed/QSO/SALVATO09/AGN_MOD.list
# # QSO_LIB    :LIB_QSO
# # QSO_LIB doc:/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_QSO.doc
# # QSO_FSCALE :1.0000
# #######################################
# Number of SED in the list 30
#  All files opened
# #######################################
# # It s computing the SYNTHETIC MAGNITUDES #
# # For Gal/QSO libraries with these OPTIONS #
# # with the following options :
# # Config file     :
# # Filter file     : filter_roman
# # Magnitude type     : AB
# # QSO_LIB_IN    :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_bin/LIB_QSO(.doc & .bin)
# # QSO_LIB_OUT   :/Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_mag/QSO_COSMOS(.doc & .bin)
# # ZGRID_TYPE   :0
# # Z_STEP   :0.0100 0.0000 3.0000
# # COSMOLOGY   :70.0000,0.3000,0.7000
# # EXTINC_LAW   :SB_calzetti.dat
# # MOD_EXTINC   :0 1000
# # EB_V   :0.0000 0.1000 0.2000 0.3000 # LIB_ASCII   YES
# # CREATION_DATE Tue Feb 18 08:26:12 2025
# #############################################
# Inserting handle into data store.  model_inform_roman: inprogress_roman.pkl, inform_roman
# User defined LEPHAREDIR is set. Code runs depend on all required
# auxiliary data being present at /Users/mteodoro/Library/Caches/lephare/data.
# User defined LEPHAREWORK is set. All intermediate files will be written to:
#  /Users/mteodoro/Library/Caches/lephare/runs/inform_roman
# Inserting handle into data store.  test_data: None, LephareEstimator
# Process 0 running estimator on chunk 0 - 18420
# Using user columns from input table assuming they are in the standard order.
# Processing 18420 objects with 8 bands
# #######################################
# # PHOTOMETRIC REDSHIFT with OPTIONS   #
# # Config file            :
# # CAT_IN                 : roman_simulated_catalog.in
# # CAT_OUT                : roman_simulated_catalog.out
# # CAT_LINES              : 0 1000000000
# # PARA_OUT               : /Users/mteodoro/Library/Caches/lephare/data/examples/output.para
# # INP_TYPE               : F
# # CAT_FMT[0:MEME 1:MMEE] : 0
# # CAT_MAG                : AB
# # ZPHOTLIB               : ROMAN_SIMULATED_MAGS
# # FIR_LIB                :
# # FIR_LMIN               : 7.000000
# # FIR_CONT               : -1.000000
# # FIR_SCALE              : -1.000000
# # FIR_FREESCALE          : YES
# # FIR_SUBSTELLAR         : NO
# # ERR_SCALE              : 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.050000 0.050000 0.050000 0.050000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.020000 0.050000 0.050000 0.050000 0.050000 0.100000 0.200000 0.300000
# # ERR_FACTOR             : 1.500000
# # GLB_CONTEXT            : 0
# # FORB_CONTEXT           : -1
# # DZ_WIN                 : 1.000000
# # MIN_THRES              : 0.020000
# # MAG_ABS                : -24.000000 -5.000000
# # MAG_ABS_AGN            : -30.000000 -10.000000
# # MAG_REF                : 2
# # NZ_PRIOR               : -2 -2
# # Z_INTERP               : YES
# # Z_METHOD               : BEST
# # PROB_INTZ              : 0.000000
# # MABS_METHOD            : 1
# # MABS_CONTEXT           : 33556478
# # MABS_REF               : 10
# # AUTO_ADAPT             : NO
# # ADAPT_BAND             : 4
# # ADAPT_LIM              : 1.500000 23.000000
# # ADAPT_ZBIN             : 0.010000 6.000000
# # ZFIX                   : NO
# # SPEC_OUT               : NO
# # CHI_OUT                : NO
# # PDZ_OUT                : test
# #######################################
# Reading input librairies ...
# Read lib
# Number of keywords to be read in the doc: 14
# Number of keywords read at the command line (excluding -c config): 0
# Reading keywords from /Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_mag/ROMAN_SIMULATED_MAGS.doc
# Number of keywords read in the config file: 17
# Keyword NUMBER_ROWS not provided
# Keyword NUMBER_SED not provided
# Keyword Z_FORM not provided
# Reading library: /Users/mteodoro/Library/Caches/lephare/runs/inform_roman/lib_mag/ROMAN_SIMULATED_MAGS.bin
#  Done with the library reading with 412370 SED read.
# Read lib out
# Read filt
# # NAME                        IDENT      Lbda_mean Lbeff(Vega)       FWHM     AB-cor      VEGA   CALIB    Fac_corr
# roman_F062.pb                 1             0.6434      0.6146      0.2191    0.1529  -21.5500       0      1.0000
# roman_F087.pb                 2             0.8765      0.8653      0.2122    0.4940  -22.6000       0      1.0000
# roman_F106.pb                 3             1.0650      1.0460      0.2627    0.6531  -23.1800       0      1.0000
# roman_F129.pb                 4             1.3000      1.2760      0.3191    0.9589  -23.9200       0      1.0000
# roman_F146.pb                 5             1.5380      1.3050      0.9562    1.0240  -24.2200       0      1.0000
# roman_F158.pb                 6             1.5880      1.5580      0.3889    1.2910  -24.6900       0      1.0000
# roman_F184.pb                 7             1.8470      1.8290      0.3142    1.5530  -25.2800       0      1.0000
# roman_F213.pb                 8             2.1310      2.1120      0.3467    1.8070  -25.8500       0      1.0000
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 254
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 255
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 256
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 260
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 357
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 386
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# WARNING: No scaling --> No z 407
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# ...
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
#  Can not add error in quadrature: dimension of min_err 8 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rcp.process()
#
# File ~/GIT/roman_photoz/.worktrees/RCAL-947-photometric-redshifts-in-romancal/roman_photoz/roman_catalog_process.py:128, in RomanCatalogProcess.process(self, input_filename, input_path)
#     126 self.get_data(input_filename=input_filename, input_path=input_path)
#     127 self.create_informer_stage()
# --> 128 self.create_estimator_stage()
#
# File ~/GIT/roman_photoz/.worktrees/RCAL-947-photometric-redshifts-in-romancal/roman_photoz/roman_catalog_process.py:123, in RomanCatalogProcess.create_estimator_stage(self)
#     104 def create_estimator_stage(self):
#     105     # take the sythetic test data, and find the best
#     106     # fits from the library. This results in a PDF, zmode,
#    (...)
#     110     # |we use rail's interface here to create the estimator stage
#     111     # |https://rail-hub.readthedocs.io/en/latest/api/rail.estimation.estimator.html
#     112     estimate_lephare = LephareEstimator.make_stage(
#     113         # name="test_Lephare_COSMOS",
#     114         nondetect_val=np.nan,
#    (...)
#     120         ref_band=self.flux_cols[0],
#     121     )
# --> 123     self.estimated = estimate_lephare.estimate(self.data)
#
# File /opt/anaconda3/envs/rcal-947/lib/python3.12/site-packages/rail/estimation/estimator.py:103, in CatEstimator.estimate(self, input_data)
#     101 self.set_data("input", input_data)
#     102 self.validate()
# --> 103 self.run()
#     104 self.finalize()
#     105 results = self.get_handle("output")
#
# File /opt/anaconda3/envs/rcal-947/lib/python3.12/site-packages/rail/estimation/estimator.py:118, in CatEstimator.run(self)
#     116 for s, e, test_data in iterator:
#     117     print(f"Process {self.rank} running estimator on chunk {s} - {e}")
# --> 118     self._process_chunk(s, e, test_data, first)
#     119     first = False
#     120     # Running garbage collection manually seems to be needed
#     121     # to avoid memory growth for some estimators
#
# File /opt/anaconda3/envs/rcal-947/lib/python3.12/site-packages/rail/estimation/algos/lephare.py:240, in LephareEstimator._process_chunk(self, start, end, data, first)
#     238 elif not self.config["offsets"]:
#     239     offsets = self.model["offsets"]
# --> 240 output, pdfs, zgrid = lp.process(
#     241     self.lephare_config, input, offsets=offsets
#     242 )
#     243 self.zgrid = zgrid
#     245 ng = data[self.config.bands[0]].shape[0]
#
# File /opt/anaconda3/envs/rcal-947/lib/python3.12/site-packages/lephare/process.py:54, in process(config, input, col_names, standard_names, filename, offsets)
#      52     one_obj = lp.onesource(i, photz.gridz)
#      53     one_obj.readsource(str(i), flux[i], flux_err[i], context[i], zspec[i], str(string_data[i]))
# ---> 54     photz.prep_data(one_obj)
#      55     srclist.append(one_obj)
#      57 # If AUTO_ADAPT set compute offsets
#
# KeyboardInterrupt:

# %%
rcp.estimated.data[13].ancil

# %%
import numpy as np

# %%
indx = 13
zmin = rcp.estimated.data[indx].ancil["zmean"] * 0.25
zmax = rcp.estimated.data[indx].ancil["zmean"] * 1.75
zgrid = np.linspace(zmin, zmax, 1000)
plt.plot(
    zgrid, np.squeeze(rcp.estimated.data[indx].pdf(zgrid)), label="Estimated PDF"
)
plt.axvline(x=rcp.data["redshift"][indx], color="r", label="True redshift")
plt.legend()
plt.xlabel("z")
plt.show()

# %%
estimate_diff_from_truth = np.abs(
    rcp.estimated.data.ancil["zmode"] - rcp.data["redshift"]
)

plt.figure()
plt.hist(estimate_diff_from_truth, 100)
plt.xlabel("abs(z_estimated - z_true)")
plt.show()

# %%
plt.scatter(rcp.data["redshift"], rcp.estimated.data.ancil["Z_BEST"])
plt.xlabel("$z_{spec}$")
plt.ylabel("$z_{LePHARE}$")

# %%
plt.scatter(rcp.data["redshift"], rcp.estimated.data.ancil["zmean"])
plt.xlabel("$z_{spec}$")
plt.ylabel("$z_{LePHARE}$")

# %%
import h5py

with h5py.File("output_test_Lephare_COSMOS.hdf5", "r") as f:
    def print_attrs(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name}")

    f.visititems(print_attrs)

# %%
import pandas as pd

df = pd.read_hdf("output_test_Lephare_COSMOS.hdf5", "data/yvals")

print(df)
